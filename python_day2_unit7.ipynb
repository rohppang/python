# %%
import csv
f = open('age.csv')
data = csv.reader(f)

result = []                     # 빈 리스트 만들기
for row in data:                
    if '신도림' in row[0]:      # '신도림'이 포함된 행정구역 찾기
        for i in row[3:] :      # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            result.append(int(i))    # 해당 연령의 인구수 리스트에 순서대로 정하기
        
print(result)
# Out:
# [335, 326, 373, 398, 392, 409, 393, 426, 429, 376, 425, 387, 356, 352, 338, 346, 344, 345, 389, 400, 369, 431, 431, 511, 461, 470, 458, 471, 489, 462, 554, 545, 575, 602, 627, 704, 770, 784, 767, 725, 714, 676, 689, 623, 697, 691, 690, 627, 639, 597, 584, 485, 506, 541, 554, 439, 530, 529, 572, 524, 520, 459, 441, 453, 432, 385, 386, 311, 267, 292, 254, 270, 252, 160, 151, 159, 159, 156, 133, 112, 118, 103, 81, 98, 55, 47, 51, 36, 31, 26, 20, 20, 9, 15, 6, 9, 5, 5, 2, 2, 8]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
import csv
f = open('age.csv')
data = csv.reader(f)

region = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:')

result = []                     # 빈 리스트 만들기
for row in data:                
    if region in row[0]:      # '신도림'이 포함된 행정구역 찾기
        for i in row[3:] :      # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            result.append(int(i))    # 해당 연령의 인구수 리스트에 순서대로 정하기
        
print(result)  

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:풍납
# [82, 93, 81, 89, 89, 79, 86, 67, 72, 88, 95, 90, 98, 92, 82, 119, 92, 94, 152, 146, 153, 199, 170, 210, 176, 207, 212, 209, 200, 218, 201, 221, 250, 220, 205, 222, 221, 259, 232, 231, 194, 205, 202, 198, 211, 214, 222, 246, 275, 251, 269, 238, 217, 245, 245, 238, 261, 255, 348, 314, 297, 312, 284, 239, 278, 201, 213, 212, 149, 150, 168, 160, 153, 110, 108, 121, 121, 117, 115, 79, 69, 84, 59, 40, 37, 34, 26, 23, 33, 17, 9, 9, 9, 5, 0, 4, 5, 4, 0, 1, 8, 167, 168, 192, 187, 196, 220, 240, 209, 215, 198, 212, 213, 186, 201, 196, 207, 212, 228, 257, 243, 250, 282, 280, 432, 453, 404, 453, 426, 392, 410, 415, 397, 400, 364, 371, 431, 455, 445, 452, 391, 443, 346, 372, 401, 406, 421, 410, 394, 435, 402, 371, 371, 348, 365, 370, 332, 356, 333, 412, 410, 341, 393, 370, 345, 348, 253, 253, 236, 191, 226, 194, 203, 213, 110, 138, 131, 134, 124, 93, 100, 76, 66, 67, 55, 48, 50, 44, 34, 30, 29, 19, 19, 13, 7, 4, 5, 11, 2, 3, 1, 7]
